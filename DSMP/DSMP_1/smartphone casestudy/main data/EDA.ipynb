# %%
import pandas as pd

# %%
df = pd.read_csv('new_clean.csv')
df.shape
# Out:
# (988, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 988 entries, 0 to 987
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Model       988 non-null    object
#  1   Price       988 non-null    object
#  2   Rating      988 non-null    float64
#  3   Spec Score  988 non-null    int64
#  4   Sim         988 non-null    object
#  5   Processor   988 non-null    object
#  6   RAM         988 non-null    object
#  7   Battery     988 non-null    object
#  8   Display     988 non-null    object
#  9   Camera      988 non-null    object
#  10  Card        698 non-null    object
#  11  OS          937 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 92.8+ KB
