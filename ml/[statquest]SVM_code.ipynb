# %%
# uci package installation for data fetching
# !pip install ucimlrepo

# %%
# imports
from ucimlrepo import fetch_ucirepo  # this is from dataset fetching
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from sklearn.utils import resample   # downsample the dataset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale   # scale and centraing data
from sklearn.svm import SVC   # Support vector machine for classification
from sklearn.model_selection import GridSearchCV   # from cross validation
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.decomposition import PCA    # perform PCA to plot the data

# %%
# fetch dataset 
default_of_credit_card_clients = fetch_ucirepo(id=350)

# %%
# some metadata about the dataset
print(default_of_credit_card_clients.metadata['name'],end='\n\n')
print(default_of_credit_card_clients.metadata['additional_info']['summary'],end='\n\n\n')
print(default_of_credit_card_clients.metadata['additional_info']['variable_info'])
# Out:
# Default of Credit Card Clients
#
# ...

# %%
# variable information 
default_of_credit_card_clients.variables
# Out:
#    name     role     type      demographic                 description units  \
# 0    ID       ID  Integer             None                        None  None
# 1    X1  Feature  Integer             None                   LIMIT_BAL  None
# 2    X2  Feature  Integer              Sex                         SEX  None
# 3    X3  Feature  Integer  Education Level                   EDUCATION  None
# 4    X4  Feature  Integer   Marital Status                    MARRIAGE  None
# 5    X5  Feature  Integer              Age                         AGE  None
# 6    X6  Feature  Integer             None                       PAY_0  None
# 7    X7  Feature  Integer             None                       PAY_2  None
# 8    X8  Feature  Integer             None                       PAY_3  None
# 9    X9  Feature  Integer             None                       PAY_4  None
# 10  X10  Feature  Integer             None                       PAY_5  None
# ...

# %%
# data (as pandas dataframes) 
X = default_of_credit_card_clients.data.features 
y = default_of_credit_card_clients.data.targets 

print(X.shape,y.shape)
# Out:
# (30000, 23) (30000, 1)

# %%
X.head()
# Out:
#        X1  X2  X3  X4  X5  X6  X7  X8  X9  X10  ...    X14    X15    X16  \
# 0   20000   2   2   1  24   2   2  -1  -1   -2  ...    689      0      0
# 1  120000   2   2   2  26  -1   2   0   0    0  ...   2682   3272   3455
# 2   90000   2   2   2  34   0   0   0   0    0  ...  13559  14331  14948
# 3   50000   2   2   1  37   0   0   0   0    0  ...  49291  28314  28959
# 4   50000   1   2   1  57  -1   0  -1   0    0  ...  35835  20940  19146
#
#      X17   X18    X19    X20   X21   X22   X23
# 0      0     0    689      0     0     0     0
# 1   3261     0   1000   1000  1000     0  2000
# 2  15549  1518   1500   1000  1000  1000  5000
# 3  29547  2000   2019   1200  1100  1069  1000
# 4  19131  2000  36681  10000  9000   689   679
#
# [5 rows x 23 columns]
